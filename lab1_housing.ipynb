# %% [markdown]
# <a href="https://colab.research.google.com/github/PabasaraRathnayake/Data_Mining_and_Warehousing/blob/main/lab1_housing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('sample_data/housing.csv')
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0          880           129.0
# 1        -122.22     37.86                21.0         7099          1106.0
# 2        -122.24     37.85                52.0         1467           190.0
# 3        -122.25     37.85                52.0         1274           235.0
# 4        -122.25     37.85                52.0         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0         1665           374.0
# 20636    -121.21     39.49                18.0          697           150.0
# 20637    -121.22     39.43                17.0         2254           485.0
# 20638    -121.32     39.43                18.0         1860           409.0
# 20639    -121.24     39.37                16.0         2785           616.0
#
# ...

# %%
df.describe() #descriptive statistics
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20639.000000  20640.000000
# mean    -119.569704     35.631861           28.638839   2635.763081
# std        2.003532      2.135952           12.585519   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20432.000000  20638.000000  20640.000000   20638.000000
# mean       537.866239   1425.503586    499.539680       3.870829
# std        421.394931   1132.508306    382.329753       1.899826
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20639 non-null  float64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20432 non-null  float64
#  5   population          20638 non-null  float64
#  6   households          20640 non-null  int64
#  7   median_income       20638 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(6), int64(3), object(1)
# memory usage: 1.6+ MB

# %%
df['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
df['population'].mean() #mean polulation
# Out:
# 1425.5035856187615

# %%
df.isnull().sum() #total number of null values in each column
# Out:
# longitude               0
# latitude                0
# housing_median_age      1
# total_rooms             0
# total_bedrooms        208
# population              2
# households              0
# median_income           2
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(df['longitude'], df['latitude'], c=df['median_house_value'], cmap='jet', alpha = 0.5)
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.title('Housing market')
plt.colorbar(label = 'Prices')
